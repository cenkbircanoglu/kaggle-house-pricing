# %% [markdown]
# # Linear Regression
#
# In this tutorial we'll walk through how one can implement *linear regression* using MXNet APIs.
#
# The function we are trying to learn is: *y = x<sub>1</sub>  +  2x<sub>2</sub>*, where *(x<sub>1</sub>,x<sub>2</sub>)* are input features and *y* is the corresponding label.
#
# ## Prerequisites
#
# To complete this tutorial, we need:
#
# - MXNet. See the instructions for your operating system in [Setup and Installation](http://mxnet.io/get_started/install.html).
#
# - [Jupyter Notebook](http://jupyter.org/index.html).
#
# ```
# $ pip install jupyter
# ```
#
# To begin, the following code imports the necessary packages we'll need for this exercise.

# %%
import mxnet as mx
import numpy as np
from read_data import load_data

import logging
logging.getLogger().setLevel(logging.DEBUG)

# %% [markdown]
# ## Preparing the Data
#
# In MXNet, data is input via **Data Iterators**. Here we will illustrate
# how to encode a dataset into an iterator that MXNet can use. The data used in the example is made up of 2D data points with corresponding integer labels.

# %%
#Training data
tr_df, tr_y, te_df = load_data()
train_data = tr_df.values
train_label = tr_y.values
batch_size = 1

#Evaluation Data
eval_data = tr_df.values
eval_label = tr_y.values

# %% [markdown]
# Once we have the data ready, we need to put it into an iterator and specify
# parameters such as `batch_size` and `shuffle`. `batch_size` specifies the number
# of examples shown to the model each time we update its parameters and `shuffle`
# tells the iterator to randomize the order in which examples are shown to the model.

# %%
train_iter = mx.io.NDArrayIter(train_data,train_label, batch_size, shuffle=True,label_name='lin_reg_label')
eval_iter = mx.io.NDArrayIter(eval_data, eval_label, batch_size, shuffle=False)

# %% [markdown]
# In the above example, we have made use of `NDArrayIter`, which is useful for iterating
# over both numpy ndarrays and MXNet NDArrays. In general, there are different types of iterators in
# MXNet and you can use one based on the type of data you are processing.
# Documentation for iterators can be found [here](http://mxnet.io/api/python/io.html).
#
# ## MXNet Classes
#
# 1. **IO:** The IO class as we already saw works on the data and carries out
#    operations such as feeding data in batches and shuffling.
#
# 2. **Symbol:** The actual MXNet neural network is composed using symbols. MXNet has
#    different types of symbols, including variable placeholders for input data,
#    neural network layers, and operators that manipulate NDArrays.
#
# 3. **Module:** The module class in MXNet is used to define the overall computation.
# 	It is initialized with the model we want to train, the training inputs (data and labels)
# 	and some additional parameters such as learning rate and the optimization
# 	algorithm to use.
#
# ## Defining the Model
#
# MXNet uses **Symbols** for defining a model. Symbols are the building blocks
# and make up various components of the model. Symbols are used to define:
#
# 1. **Variables:** A variable is a placeholder for future data. This symbol is used
#    to define a spot which will be filled with training data/labels in the future
#    when we commence training.
# 2. **Neural Network Layers:** The layers of a network or any other type of model are
#    also defined by Symbols. Such a symbol takes one or more previous symbols as
#    inputs, performs some transformations on them, and creates one or more outputs.
#    One such example is the `FullyConnected` symbol which specifies a fully connected
#    layer of a neural network.
# 3. **Outputs:** Output symbols are MXNet's way of defining a loss. They are
#    suffixed with the word "Output" (eg. the `SoftmaxOutput` layer). You can also
#    [create your own loss function](https://github.com/dmlc/mxnet/blob/master/docs/tutorials/r/CustomLossFunction.md#how-to-use-your-own-loss-function).
#    Some examples of existing losses are: `LinearRegressionOutput`, which computes
#    the l2-loss between it's input symbol and the labels provided to it;
#    `SoftmaxOutput`, which computes the categorical cross-entropy.
#
# The ones described above and other symbols are chained together with the output of
# one symbol serving as input to the next to build the network topology. More information
# about the different types of symbols can be found [here](http://mxnet.io/api/python/symbol.html).

# %%
X = mx.sym.Variable('data')
Y = mx.symbol.Variable('lin_reg_label')
fc1  = mx.sym.FullyConnected(data=X, name='fc1', num_hidden=64)
act1 = mx.sym.Activation(data=fc1, act_type="tanh")
fc2  = mx.sym.FullyConnected(data=act1, name='fc2', num_hidden=32)
act2 = mx.sym.Activation(data=fc2, act_type="tanh")
fc3  = mx.sym.FullyConnected(data=act2, name='fc3', num_hidden=1)
lro = mx.sym.LinearRegressionOutput(data=fc3, label=Y, name="lro")

# %% [markdown]
# The above network uses the following layers:
#
# 1. `FullyConnected`: The fully connected symbol represents a fully connected layer
#    of a neural network (without any activation being applied), which in essence,
#    is just a linear regression on the input attributes. It takes the following
#    parameters:
#
#    - `data`: Input to the layer (specifies the symbol whose output should be fed here)
#    - `num_hidden`: Number of hidden neurons in the layer, which is same as the dimensionality
#      of the layer's output
#
# 2. `LinearRegressionOutput`: Output layers in MXNet compute training loss, which is
# 	the measure of inaccuracy in the model's predictions. The goal of training is to minimize the
# 	training loss. In our example, the `LinearRegressionOutput` layer computes the *l2* loss against
# 	its input and the labels provided to it. The parameters to this layer are:
#
#    - `data`: Input to this layer (specifies the symbol whose output should be fed here)
#    - `label`: The training labels against which we will compare the input to the layer for calculation of l2 loss
#
# **Note on naming convention:** the label variable's name should be the same as the
# `label_name` parameter passed to your training data iterator. The default value of
# this is `softmax_label`, but we have updated it to `lin_reg_label` in this
# tutorial as you can see in `Y = mx.symbol.Variable('lin_reg_label')` and
# `train_iter = mx.io.NDArrayIter(..., label_name='lin_reg_label')`.
#
# Finally, the network is input to a *Module*, where we specify the symbol
# whose output needs to be minimized (in our case, `lro` or the `lin_reg_output`), the
# learning rate to be used while optimization and the number of epochs we want to
# train our model for.

# %%
model = mx.mod.Module(
    symbol = lro ,
    data_names=['data'],
    label_names = ['lin_reg_label']# network structure
)

# %% [markdown]
# We can visualize the network we created by plotting it:

# %%
mx.viz.plot_network(symbol=lro)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/.virtualenvs/udacity/lib/python3.6/site-packages/graphviz/backend.py in pipe(engine, format, data, quiet)
#     153             stdout=subprocess.PIPE, stderr=subprocess.PIPE,
# --> 154             startupinfo=STARTUPINFO)
#     155     except OSError as e:
#
# /usr/local/Cellar/python3/3.6.3/Frameworks/Python.framework/Versions/3.6/lib/python3.6/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors)
#     708                                 errread, errwrite,
# --> 709                                 restore_signals, start_new_session)
#     710         except:
#
# /usr/local/Cellar/python3/3.6.3/Frameworks/Python.framework/Versions/3.6/lib/python3.6/subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, start_new_session)
#    1343                             err_msg += ': ' + repr(err_filename)
# -> 1344                     raise child_exception_type(errno_num, err_msg, err_filename)
#    1345                 raise child_exception_type(err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'dot': 'dot'
#
# During handling of the above exception, another exception occurred:
#
# ExecutableNotFound                        Traceback (most recent call last)
# ~/.virtualenvs/udacity/lib/python3.6/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~/.virtualenvs/udacity/lib/python3.6/site-packages/graphviz/files.py in _repr_svg_(self)
#     103
#     104     def _repr_svg_(self):
# --> 105         return self.pipe(format='svg').decode(self._encoding)
#     106
#     107     def pipe(self, format=None):
#
# ~/.virtualenvs/udacity/lib/python3.6/site-packages/graphviz/files.py in pipe(self, format)
#     122         data = text_type(self.source).encode(self._encoding)
#     123
# --> 124         outs = backend.pipe(self._engine, format, data)
#     125
#     126         return outs
#
# ~/.virtualenvs/udacity/lib/python3.6/site-packages/graphviz/backend.py in pipe(engine, format, data, quiet)
#     155     except OSError as e:
#     156         if e.errno == errno.ENOENT:
# --> 157             raise ExecutableNotFound(args)
#     158         else:  # pragma: no cover
#     159             raise
#
# ExecutableNotFound: failed to execute ['dot', '-Tsvg'], make sure the Graphviz executables are on your systems' PATH

# %% [markdown]
# ## Training the model
#
# Once we have defined the model structure, the next step is to train the
# parameters of the model to fit the training data. This is accomplished using the
# `fit()` function of the `Module` class.

# %%
model.fit(train_iter, eval_iter,
            num_epoch=50,
            optimizer='adam',
            eval_metric='mse',
            batch_end_callback = mx.callback.Speedometer(batch_size, 2))
# Out:
# INFO:root:Epoch[0] Batch [2]	Speed: 1043.23 samples/sec	mse=57296576170.666664
# INFO:root:Epoch[0] Batch [4]	Speed: 822.01 samples/sec	mse=1937748160.000000
# INFO:root:Epoch[0] Batch [6]	Speed: 1107.41 samples/sec	mse=17395857408.000000
# INFO:root:Epoch[0] Batch [8]	Speed: 782.81 samples/sec	mse=56494229504.000000
# INFO:root:Epoch[0] Batch [10]	Speed: 700.80 samples/sec	mse=9101213440.000000
# INFO:root:Epoch[0] Batch [12]	Speed: 857.20 samples/sec	mse=13510394880.000000
# INFO:root:Epoch[0] Batch [14]	Speed: 1059.84 samples/sec	mse=6735023744.710938
# INFO:root:Epoch[0] Batch [16]	Speed: 1158.17 samples/sec	mse=9844150784.000000
# INFO:root:Epoch[0] Batch [18]	Speed: 882.27 samples/sec	mse=4154349952.000000
# INFO:root:Epoch[0] Batch [20]	Speed: 887.68 samples/sec	mse=9598433792.000000
# INFO:root:Epoch[0] Batch [22]	Speed: 865.07 samples/sec	mse=4288341632.000000
# INFO:root:Epoch[0] Batch [24]	Speed: 1097.12 samples/sec	mse=14413316352.000000
# INFO:root:Epoch[0] Batch [26]	Speed: 729.38 samples/sec	mse=586086688.000000
# INFO:root:Epoch[0] Batch [28]	Speed: 832.29 samples/sec	mse=710808352.000000
# INFO:root:Epoch[0] Batch [30]	Speed: 778.24 samples/sec	mse=145732800.000000
# INFO:root:Epoch[0] Batch [32]	Speed: 1049.23 samples/sec	mse=5154185760.000000
# INFO:root:Epoch[0] Batch [34]	Speed: 1403.48 samples/sec	mse=24485663280.000000
# INFO:root:Epoch[0] Batch [36]	Speed: 1119.68 samples/sec	mse=3171248416.000000
# INFO:root:Epoch[0] Batch [38]	Speed: 1270.04 samples/sec	mse=19029126144.000000
# INFO:root:Epoch[0] Batch [40]	Speed: 1066.17 samples/sec	mse=19465736704.000000
# INFO:root:Epoch[0] Batch [42]	Speed: 796.79 samples/sec	mse=730621600.000000
# INFO:root:Epoch[0] Batch [44]	Speed: 755.32 samples/sec	mse=7033746688.000000
# INFO:root:Epoch[0] Batch [46]	Speed: 655.51 samples/sec	mse=73784252928.000000
# INFO:root:Epoch[0] Batch [48]	Speed: 640.84 samples/sec	mse=28648412584.500000
# INFO:root:Epoch[0] Batch [50]	Speed: 886.18 samples/sec	mse=5679010688.000000
# INFO:root:Epoch[0] Batch [52]	Speed: 693.45 samples/sec	mse=102997063680.000000
# INFO:root:Epoch[0] Batch [54]	Speed: 1076.43 samples/sec	mse=46498699264.000000
# INFO:root:Epoch[0] Batch [56]	Speed: 1261.07 samples/sec	mse=568958032.000000
# INFO:root:Epoch[0] Batch [58]	Speed: 1212.23 samples/sec	mse=45056687104.000000
# INFO:root:Epoch[0] Batch [60]	Speed: 1078.23 samples/sec	mse=109621544704.000000
# INFO:root:Epoch[0] Batch [62]	Speed: 991.56 samples/sec	mse=747690032.000000
# INFO:root:Epoch[0] Batch [64]	Speed: 657.11 samples/sec	mse=3597786304.000000
# INFO:root:Epoch[0] Batch [66]	Speed: 876.83 samples/sec	mse=23064205312.000000
# INFO:root:Epoch[0] Batch [68]	Speed: 753.29 samples/sec	mse=12370629888.000000
# INFO:root:Epoch[0] Batch [70]	Speed: 990.62 samples/sec	mse=8282301696.000000
# INFO:root:Epoch[0] Batch [72]	Speed: 971.80 samples/sec	mse=8063861824.000000
# INFO:root:Epoch[0] Batch [74]	Speed: 730.71 samples/sec	mse=6051998480.000000
# INFO:root:Epoch[0] Batch [76]	Speed: 648.92 samples/sec	mse=17336529157.000000
# INFO:root:Epoch[0] Batch [78]	Speed: 683.56 samples/sec	mse=2408287488.000000
# INFO:root:Epoch[0] Batch [80]	Speed: 715.57 samples/sec	mse=6071730208.000000
# INFO:root:Epoch[0] Batch [82]	Speed: 731.03 samples/sec	mse=22863564288.000000
# INFO:root:Epoch[0] Batch [84]	Speed: 837.19 samples/sec	mse=7961687168.000000
# INFO:root:Epoch[0] Batch [86]	Speed: 667.78 samples/sec	mse=14064902784.000000
# INFO:root:Epoch[0] Batch [88]	Speed: 1164.11 samples/sec	mse=18896984064.000000
# INFO:root:Epoch[0] Batch [90]	Speed: 1289.56 samples/sec	mse=1819350528.000000
# INFO:root:Epoch[0] Batch [92]	Speed: 1239.27 samples/sec	mse=16703425024.000000
# INFO:root:Epoch[0] Batch [94]	Speed: 1028.39 samples/sec	mse=12780226304.000000
# INFO:root:Epoch[0] Batch [96]	Speed: 694.71 samples/sec	mse=1413620996.000000
# INFO:root:Epoch[0] Batch [98]	Speed: 647.47 samples/sec	mse=969306568.000000
# INFO:root:Epoch[0] Batch [100]	Speed: 703.45 samples/sec	mse=1201487000.000000
# INFO:root:Epoch[0] Batch [102]	Speed: 784.28 samples/sec	mse=15488936096.000000
# INFO:root:Epoch[0] Batch [104]	Speed: 793.10 samples/sec	mse=4913060772.000000
# INFO:root:Epoch[0] Batch [106]	Speed: 1152.76 samples/sec	mse=1030326560.000000
# INFO:root:Epoch[0] Batch [108]	Speed: 1135.59 samples/sec	mse=10673328256.000000
# INFO:root:Epoch[0] Batch [110]	Speed: 1274.09 samples/sec	mse=8567558656.000000
# INFO:root:Epoch[0] Batch [112]	Speed: 1432.73 samples/sec	mse=7739269504.000000
# INFO:root:Epoch[0] Batch [114]	Speed: 1097.70 samples/sec	mse=481492672.375000
# INFO:root:Epoch[0] Batch [116]	Speed: 955.10 samples/sec	mse=6866684672.000000
# INFO:root:Epoch[0] Batch [118]	Speed: 777.59 samples/sec	mse=7781979904.000000
# INFO:root:Epoch[0] Batch [120]	Speed: 840.71 samples/sec	mse=16167571680.000000
# INFO:root:Epoch[0] Batch [122]	Speed: 833.28 samples/sec	mse=6017027136.000000
# INFO:root:Epoch[0] Batch [124]	Speed: 946.15 samples/sec	mse=13570358272.000000
# INFO:root:Epoch[0] Batch [126]	Speed: 901.23 samples/sec	mse=7075991040.000000
# INFO:root:Epoch[0] Batch [128]	Speed: 751.06 samples/sec	mse=15222917888.000000
# INFO:root:Epoch[0] Batch [130]	Speed: 886.18 samples/sec	mse=625040740.000000
# INFO:root:Epoch[0] Batch [132]	Speed: 985.74 samples/sec	mse=9201485312.000000
# INFO:root:Epoch[0] Batch [134]	Speed: 989.57 samples/sec	mse=63681092.000000
# INFO:root:Epoch[0] Batch [136]	Speed: 1068.88 samples/sec	mse=5084961664.000000
# INFO:root:Epoch[0] Batch [138]	Speed: 828.10 samples/sec	mse=14170730496.000000
# INFO:root:Epoch[0] Batch [140]	Speed: 678.20 samples/sec	mse=1047602184.000000
# INFO:root:Epoch[0] Batch [142]	Speed: 953.79 samples/sec	mse=2067776448.000000
# INFO:root:Epoch[0] Batch [144]	Speed: 1013.12 samples/sec	mse=14534213952.000000
# INFO:root:Epoch[0] Batch [146]	Speed: 983.77 samples/sec	mse=6618833280.000000
# INFO:root:Epoch[0] Batch [148]	Speed: 985.74 samples/sec	mse=2806432136.000000
# INFO:root:Epoch[0] Batch [150]	Speed: 1126.90 samples/sec	mse=426974238.000000
# INFO:root:Epoch[0] Batch [152]	Speed: 909.24 samples/sec	mse=2327006176.000000
# INFO:root:Epoch[0] Batch [154]	Speed: 1007.04 samples/sec	mse=193904182.000000
# INFO:root:Epoch[0] Batch [156]	Speed: 1114.91 samples/sec	mse=1826351256.000000
# INFO:root:Epoch[0] Batch [158]	Speed: 679.13 samples/sec	mse=2940449808.000000
# INFO:root:Epoch[0] Batch [160]	Speed: 748.85 samples/sec	mse=20673997824.000000
# INFO:root:Epoch[0] Batch [162]	Speed: 783.10 samples/sec	mse=1479430192.000000
# INFO:root:Epoch[0] Batch [164]	Speed: 878.30 samples/sec	mse=127892826.000000
# INFO:root:Epoch[0] Batch [166]	Speed: 987.13 samples/sec	mse=14883925504.000000
# INFO:root:Epoch[0] Batch [168]	Speed: 1204.05 samples/sec	mse=2489524992.000000
# INFO:root:Epoch[0] Batch [170]	Speed: 1104.93 samples/sec	mse=571769864.000000
# INFO:root:Epoch[0] Batch [172]	Speed: 1161.54 samples/sec	mse=34377922560.000000
# INFO:root:Epoch[0] Batch [174]	Speed: 1169.80 samples/sec	mse=5947465016.000000
# INFO:root:Epoch[0] Batch [176]	Speed: 717.34 samples/sec	mse=913690688.000000
# INFO:root:Epoch[0] Batch [178]	Speed: 931.03 samples/sec	mse=9471102464.000000
# INFO:root:Epoch[0] Batch [180]	Speed: 1322.92 samples/sec	mse=9532628736.000000
# INFO:root:Epoch[0] Batch [182]	Speed: 1240.00 samples/sec	mse=14341207552.000000
# INFO:root:Epoch[0] Batch [184]	Speed: 903.26 samples/sec	mse=11329063424.000000
# INFO:root:Epoch[0] Batch [186]	Speed: 758.19 samples/sec	mse=57628844338.000000
# INFO:root:Epoch[0] Batch [188]	Speed: 940.64 samples/sec	mse=3498353695.750000
# INFO:root:Epoch[0] Batch [190]	Speed: 769.17 samples/sec	mse=4352174784.000000
# INFO:root:Epoch[0] Batch [192]	Speed: 678.47 samples/sec	mse=14206932288.000000
# INFO:root:Epoch[0] Batch [194]	Speed: 973.16 samples/sec	mse=5797019264.000000
# INFO:root:Epoch[0] Batch [196]	Speed: 1039.35 samples/sec	mse=14589988416.000000
# INFO:root:Epoch[0] Batch [198]	Speed: 1253.90 samples/sec	mse=25090805376.000000
# INFO:root:Epoch[0] Batch [200]	Speed: 922.13 samples/sec	mse=5480836576.000000
# INFO:root:Epoch[0] Batch [202]	Speed: 1131.15 samples/sec	mse=1056067200.000000
# INFO:root:Epoch[0] Batch [204]	Speed: 1361.35 samples/sec	mse=8546896348.000000
# INFO:root:Epoch[0] Batch [206]	Speed: 1206.30 samples/sec	mse=380498904.000000
# INFO:root:Epoch[0] Batch [208]	Speed: 1048.31 samples/sec	mse=1159954771.000000
# INFO:root:Epoch[0] Batch [210]	Speed: 1175.70 samples/sec	mse=4456930160.000000
# INFO:root:Epoch[0] Batch [212]	Speed: 1164.92 samples/sec	mse=562229343.500000
# INFO:root:Epoch[0] Batch [214]	Speed: 944.24 samples/sec	mse=2630879872.000000
# INFO:root:Epoch[0] Batch [216]	Speed: 1030.92 samples/sec	mse=5756925628.000000
# INFO:root:Epoch[0] Batch [218]	Speed: 1167.52 samples/sec	mse=1416910800.000000
# INFO:root:Epoch[0] Batch [220]	Speed: 1250.72 samples/sec	mse=1413221344.000000
# INFO:root:Epoch[0] Batch [222]	Speed: 954.12 samples/sec	mse=13278379008.000000
# INFO:root:Epoch[0] Batch [224]	Speed: 1479.21 samples/sec	mse=1719456768.000000
# INFO:root:Epoch[0] Batch [226]	Speed: 914.99 samples/sec	mse=1645754560.000000
# INFO:root:Epoch[0] Batch [228]	Speed: 996.04 samples/sec	mse=4924480256.000000
# INFO:root:Epoch[0] Batch [230]	Speed: 816.25 samples/sec	mse=19183579648.000000
# INFO:root:Epoch[0] Batch [232]	Speed: 634.16 samples/sec	mse=13990341168.875000
# INFO:root:Epoch[0] Batch [234]	Speed: 658.50 samples/sec	mse=237199128.000000
# INFO:root:Epoch[0] Batch [236]	Speed: 896.89 samples/sec	mse=637541804.125000
# INFO:root:Epoch[0] Batch [238]	Speed: 1272.16 samples/sec	mse=1096574112.000000
# INFO:root:Epoch[0] Batch [240]	Speed: 1326.26 samples/sec	mse=1970493312.000000
# INFO:root:Epoch[0] Batch [242]	Speed: 1147.40 samples/sec	mse=18553072768.000000
# INFO:root:Epoch[0] Batch [244]	Speed: 983.19 samples/sec	mse=13318092288.000000
# INFO:root:Epoch[0] Batch [246]	Speed: 963.32 samples/sec	mse=2348456092.000000
# INFO:root:Epoch[0] Batch [248]	Speed: 1104.49 samples/sec	mse=36269685504.000000
# INFO:root:Epoch[0] Batch [250]	Speed: 876.83 samples/sec	mse=4516587168.000000
# INFO:root:Epoch[0] Batch [252]	Speed: 1273.90 samples/sec	mse=15901454336.000000
# INFO:root:Epoch[0] Batch [254]	Speed: 1372.48 samples/sec	mse=11730780160.000000
# INFO:root:Epoch[0] Batch [256]	Speed: 1225.51 samples/sec	mse=1480529504.000000
# INFO:root:Epoch[0] Batch [258]	Speed: 1137.13 samples/sec	mse=2070994566.000000
# INFO:root:Epoch[0] Batch [260]	Speed: 1388.84 samples/sec	mse=24664590592.000000
# INFO:root:Epoch[0] Batch [262]	Speed: 1119.38 samples/sec	mse=69425918.416992
# INFO:root:Epoch[0] Batch [264]	Speed: 1064.41 samples/sec	mse=5256037600.000000
# INFO:root:Epoch[0] Batch [266]	Speed: 1088.16 samples/sec	mse=1844560480.000000
# INFO:root:Epoch[0] Batch [268]	Speed: 1041.67 samples/sec	mse=7993345856.000000
# INFO:root:Epoch[0] Batch [270]	Speed: 1308.06 samples/sec	mse=11757113088.000000
# INFO:root:Epoch[0] Batch [272]	Speed: 1389.99 samples/sec	mse=3139112946.000000
# INFO:root:Epoch[0] Batch [274]	Speed: 1079.34 samples/sec	mse=4909546528.000000
# INFO:root:Epoch[0] Batch [276]	Speed: 1233.07 samples/sec	mse=14860375200.000000
# INFO:root:Epoch[0] Batch [278]	Speed: 880.69 samples/sec	mse=2804252032.000000
# INFO:root:Epoch[0] Batch [280]	Speed: 809.71 samples/sec	mse=342842976.000000
# INFO:root:Epoch[0] Batch [282]	Speed: 674.05 samples/sec	mse=197397844.000000
# INFO:root:Epoch[0] Batch [284]	Speed: 768.05 samples/sec	mse=21033764608.000000
# INFO:root:Epoch[0] Batch [286]	Speed: 1167.03 samples/sec	mse=12269095424.000000
# INFO:root:Epoch[0] Batch [288]	Speed: 1135.13 samples/sec	mse=24482570752.000000
# INFO:root:Epoch[0] Batch [290]	Speed: 1290.36 samples/sec	mse=19392615936.000000
# INFO:root:Epoch[0] Batch [292]	Speed: 849.91 samples/sec	mse=1742157792.000000
# INFO:root:Epoch[0] Batch [294]	Speed: 975.19 samples/sec	mse=29939080384.000000
# INFO:root:Epoch[0] Batch [296]	Speed: 963.32 samples/sec	mse=333158640.000000
# INFO:root:Epoch[0] Batch [298]	Speed: 838.19 samples/sec	mse=979898016.000000
# INFO:root:Epoch[0] Batch [300]	Speed: 1048.18 samples/sec	mse=12350035456.000000
# INFO:root:Epoch[0] Batch [302]	Speed: 1227.84 samples/sec	mse=3750749312.000000
# INFO:root:Epoch[0] Batch [304]	Speed: 1089.43 samples/sec	mse=559753376.000000
# INFO:root:Epoch[0] Batch [306]	Speed: 960.56 samples/sec	mse=1404414992.000000
# INFO:root:Epoch[0] Batch [308]	Speed: 1035.12 samples/sec	mse=2242849216.000000
# INFO:root:Epoch[0] Batch [310]	Speed: 1294.54 samples/sec	mse=1433362176.000000
# INFO:root:Epoch[0] Batch [312]	Speed: 1273.12 samples/sec	mse=10670392960.000000
# INFO:root:Epoch[0] Batch [314]	Speed: 1075.74 samples/sec	mse=6431141566.062500
# INFO:root:Epoch[0] Batch [316]	Speed: 1107.41 samples/sec	mse=6214983040.000000
# INFO:root:Epoch[0] Batch [318]	Speed: 1199.06 samples/sec	mse=12088281600.000000
# INFO:root:Epoch[0] Batch [320]	Speed: 1134.36 samples/sec	mse=5000467456.000000
# INFO:root:Epoch[0] Batch [322]	Speed: 1255.40 samples/sec	mse=5974832128.000000
# INFO:root:Epoch[0] Batch [324]	Speed: 1164.11 samples/sec	mse=5958302432.000000
# INFO:root:Epoch[0] Batch [326]	Speed: 1005.47 samples/sec	mse=55334543040.000000
# INFO:root:Epoch[0] Batch [328]	Speed: 1213.63 samples/sec	mse=9067053952.000000
# INFO:root:Epoch[0] Batch [330]	Speed: 1078.23 samples/sec	mse=17005972176.000000
# INFO:root:Epoch[0] Batch [332]	Speed: 1000.91 samples/sec	mse=37215941632.000000
# INFO:root:Epoch[0] Batch [334]	Speed: 1135.74 samples/sec	mse=2901213312.000000
# INFO:root:Epoch[0] Batch [336]	Speed: 886.93 samples/sec	mse=7904631808.000000
# INFO:root:Epoch[0] Batch [338]	Speed: 709.28 samples/sec	mse=64448397824.000000
# INFO:root:Epoch[0] Batch [340]	Speed: 1138.36 samples/sec	mse=2894611696.000000
# INFO:root:Epoch[0] Batch [342]	Speed: 717.59 samples/sec	mse=2121226216.000000
# INFO:root:Epoch[0] Batch [344]	Speed: 846.65 samples/sec	mse=17063152640.000000
# INFO:root:Epoch[0] Batch [346]	Speed: 1079.34 samples/sec	mse=9959433216.000000
# INFO:root:Epoch[0] Batch [348]	Speed: 842.48 samples/sec	mse=10277713920.000000
# INFO:root:Epoch[0] Batch [350]	Speed: 1133.90 samples/sec	mse=1552879423.371094
# INFO:root:Epoch[0] Batch [352]	Speed: 929.90 samples/sec	mse=839120051.000000
# INFO:root:Epoch[0] Batch [354]	Speed: 776.36 samples/sec	mse=4149504384.000000
# INFO:root:Epoch[0] Batch [356]	Speed: 891.65 samples/sec	mse=9368202835.000000
# INFO:root:Epoch[0] Batch [358]	Speed: 1193.94 samples/sec	mse=6282784128.000000
# INFO:root:Epoch[0] Batch [360]	Speed: 922.43 samples/sec	mse=2315086848.000000
# INFO:root:Epoch[0] Batch [362]	Speed: 844.52 samples/sec	mse=7387628544.000000
# INFO:root:Epoch[0] Batch [364]	Speed: 1095.26 samples/sec	mse=2187203824.000000
# INFO:root:Epoch[0] Batch [366]	Speed: 729.38 samples/sec	mse=840652960.000000
# INFO:root:Epoch[0] Batch [368]	Speed: 892.79 samples/sec	mse=1379722070.000000
# INFO:root:Epoch[0] Batch [370]	Speed: 791.45 samples/sec	mse=6932488076.125000
# INFO:root:Epoch[0] Batch [372]	Speed: 818.32 samples/sec	mse=6690336688.000000
# INFO:root:Epoch[0] Batch [374]	Speed: 788.25 samples/sec	mse=6182639360.000000
# INFO:root:Epoch[0] Batch [376]	Speed: 607.91 samples/sec	mse=1799044282.955078
# INFO:root:Epoch[0] Batch [378]	Speed: 495.66 samples/sec	mse=11526464512.000000
# INFO:root:Epoch[0] Batch [380]	Speed: 619.59 samples/sec	mse=73129676.000000
# INFO:root:Epoch[0] Batch [382]	Speed: 797.47 samples/sec	mse=232237152.000000
# INFO:root:Epoch[0] Batch [384]	Speed: 904.53 samples/sec	mse=7535722752.000000
# INFO:root:Epoch[0] Batch [386]	Speed: 701.51 samples/sec	mse=5998705920.000000
# INFO:root:Epoch[0] Batch [388]	Speed: 1248.30 samples/sec	mse=1127151946.000000
# INFO:root:Epoch[0] Batch [390]	Speed: 1100.29 samples/sec	mse=12165724032.000000
# INFO:root:Epoch[0] Batch [392]	Speed: 770.73 samples/sec	mse=1413437533.750000
# INFO:root:Epoch[0] Batch [394]	Speed: 1146.77 samples/sec	mse=2417720032.000000
# INFO:root:Epoch[0] Batch [396]	Speed: 1084.50 samples/sec	mse=2572932736.000000
# INFO:root:Epoch[0] Batch [398]	Speed: 1132.52 samples/sec	mse=13187731744.000000
# INFO:root:Epoch[0] Batch [400]	Speed: 1212.05 samples/sec	mse=2659283830.500000
# INFO:root:Epoch[0] Batch [402]	Speed: 1048.31 samples/sec	mse=467065384.000000
# INFO:root:Epoch[0] Batch [404]	Speed: 811.98 samples/sec	mse=4140339072.000000
# INFO:root:Epoch[0] Batch [406]	Speed: 807.76 samples/sec	mse=1330409008.000000
# INFO:root:Epoch[0] Batch [408]	Speed: 1017.91 samples/sec	mse=3420019968.000000
# INFO:root:Epoch[0] Batch [410]	Speed: 1042.19 samples/sec	mse=2466128384.000000
# INFO:root:Epoch[0] Batch [412]	Speed: 1002.94 samples/sec	mse=989225968.000000
# INFO:root:Epoch[0] Batch [414]	Speed: 1079.34 samples/sec	mse=10736382720.000000
# INFO:root:Epoch[0] Batch [416]	Speed: 1083.94 samples/sec	mse=3663776256.000000
# INFO:root:Epoch[0] Batch [418]	Speed: 1075.74 samples/sec	mse=434896928.000000
# INFO:root:Epoch[0] Batch [420]	Speed: 784.94 samples/sec	mse=14722418688.000000
# INFO:root:Epoch[0] Batch [422]	Speed: 1027.64 samples/sec	mse=6849023744.000000
# INFO:root:Epoch[0] Batch [424]	Speed: 1114.77 samples/sec	mse=460283658.000000
# INFO:root:Epoch[0] Batch [426]	Speed: 934.04 samples/sec	mse=533740140.000000
# INFO:root:Epoch[0] Batch [428]	Speed: 806.21 samples/sec	mse=5700091648.000000
# INFO:root:Epoch[0] Batch [430]	Speed: 975.53 samples/sec	mse=4087052992.000000
# INFO:root:Epoch[0] Batch [432]	Speed: 827.52 samples/sec	mse=863090454.066406
# INFO:root:Epoch[0] Batch [434]	Speed: 953.36 samples/sec	mse=17035752448.000000
# INFO:root:Epoch[0] Batch [436]	Speed: 1018.28 samples/sec	mse=9512073472.000000
# INFO:root:Epoch[0] Batch [438]	Speed: 970.90 samples/sec	mse=183201588.000000
# INFO:root:Epoch[0] Batch [440]	Speed: 1058.77 samples/sec	mse=8489492936.000000
# INFO:root:Epoch[0] Batch [442]	Speed: 1183.49 samples/sec	mse=5470048960.000000
# INFO:root:Epoch[0] Batch [444]	Speed: 1058.23 samples/sec	mse=946332656.000000
# INFO:root:Epoch[0] Batch [446]	Speed: 1247.56 samples/sec	mse=1069094912.000000
# INFO:root:Epoch[0] Batch [448]	Speed: 1412.46 samples/sec	mse=2568078752.000000
# INFO:root:Epoch[0] Batch [450]	Speed: 1148.81 samples/sec	mse=14337239040.000000
# INFO:root:Epoch[0] Batch [452]	Speed: 923.45 samples/sec	mse=8163416382.000000
# INFO:root:Epoch[0] Batch [454]	Speed: 1141.46 samples/sec	mse=13586199808.000000
# INFO:root:Epoch[0] Batch [456]	Speed: 1034.10 samples/sec	mse=10885011696.000000
# INFO:root:Epoch[0] Batch [458]	Speed: 1142.86 samples/sec	mse=51267868672.000000
# INFO:root:Epoch[0] Batch [460]	Speed: 1046.09 samples/sec	mse=39050800128.000000
# INFO:root:Epoch[0] Batch [462]	Speed: 1065.49 samples/sec	mse=38112997120.000000
# INFO:root:Epoch[0] Batch [464]	Speed: 1118.03 samples/sec	mse=3598705920.000000
# INFO:root:Epoch[0] Batch [466]	Speed: 1122.37 samples/sec	mse=1080924288.000000
# INFO:root:Epoch[0] Batch [468]	Speed: 927.33 samples/sec	mse=10480461532.609375
# INFO:root:Epoch[0] Batch [470]	Speed: 734.55 samples/sec	mse=66554617856.000000
# INFO:root:Epoch[0] Batch [472]	Speed: 1016.31 samples/sec	mse=6351845376.000000
# INFO:root:Epoch[0] Batch [474]	Speed: 1183.33 samples/sec	mse=20385418496.000000
# INFO:root:Epoch[0] Batch [476]	Speed: 958.37 samples/sec	mse=18630188544.000000
# INFO:root:Epoch[0] Batch [478]	Speed: 1242.94 samples/sec	mse=28886843392.000000
# INFO:root:Epoch[0] Batch [480]	Speed: 1169.63 samples/sec	mse=16025349504.000000
# INFO:root:Epoch[0] Batch [482]	Speed: 1264.30 samples/sec	mse=4544014344.000000
# INFO:root:Epoch[0] Batch [484]	Speed: 1210.48 samples/sec	mse=604469856.000000
# INFO:root:Epoch[0] Batch [486]	Speed: 850.34 samples/sec	mse=21232512320.000000
# INFO:root:Epoch[0] Batch [488]	Speed: 1043.88 samples/sec	mse=20054703104.000000
# INFO:root:Epoch[0] Batch [490]	Speed: 1048.18 samples/sec	mse=7602174464.000000
# INFO:root:Epoch[0] Batch [492]	Speed: 1037.30 samples/sec	mse=3825410816.000000
# INFO:root:Epoch[0] Batch [494]	Speed: 1201.46 samples/sec	mse=3925850432.000000
# INFO:root:Epoch[0] Batch [496]	Speed: 1170.94 samples/sec	mse=1712348224.000000
# INFO:root:Epoch[0] Batch [498]	Speed: 1380.39 samples/sec	mse=28805682176.000000
# INFO:root:Epoch[0] Batch [500]	Speed: 714.53 samples/sec	mse=12244127488.000000
# INFO:root:Epoch[0] Batch [502]	Speed: 909.04 samples/sec	mse=206242462.000000
# INFO:root:Epoch[0] Batch [504]	Speed: 1029.78 samples/sec	mse=12375290624.000000
# INFO:root:Epoch[0] Batch [506]	Speed: 887.31 samples/sec	mse=14225771008.000000
# INFO:root:Epoch[0] Batch [508]	Speed: 1018.28 samples/sec	mse=21908243200.000000
# INFO:root:Epoch[0] Batch [510]	Speed: 1161.54 samples/sec	mse=5592406256.000000
# INFO:root:Epoch[0] Batch [512]	Speed: 1217.33 samples/sec	mse=17061714944.000000
# INFO:root:Epoch[0] Batch [514]	Speed: 731.48 samples/sec	mse=7688750528.000000
# INFO:root:Epoch[0] Batch [516]	Speed: 846.65 samples/sec	mse=1302815129.468750
# INFO:root:Epoch[0] Batch [518]	Speed: 834.02 samples/sec	mse=5937070592.000000
# INFO:root:Epoch[0] Batch [520]	Speed: 1080.45 samples/sec	mse=4740339720.000000
# INFO:root:Epoch[0] Batch [522]	Speed: 1165.57 samples/sec	mse=4534259200.000000
# INFO:root:Epoch[0] Batch [524]	Speed: 1020.88 samples/sec	mse=590166656.000000
# INFO:root:Epoch[0] Batch [526]	Speed: 926.82 samples/sec	mse=812577568.000000
# INFO:root:Epoch[0] Batch [528]	Speed: 1021.88 samples/sec	mse=827509173.750000
# INFO:root:Epoch[0] Batch [530]	Speed: 849.65 samples/sec	mse=1361717728.000000
# INFO:root:Epoch[0] Batch [532]	Speed: 830.23 samples/sec	mse=33049412864.000000
# INFO:root:Epoch[0] Batch [534]	Speed: 712.71 samples/sec	mse=10105834576.000000
# INFO:root:Epoch[0] Batch [536]	Speed: 675.90 samples/sec	mse=51800377344.000000
# INFO:root:Epoch[0] Batch [538]	Speed: 673.41 samples/sec	mse=18820961408.000000
# INFO:root:Epoch[0] Batch [540]	Speed: 1040.51 samples/sec	mse=11438655936.000000
# INFO:root:Epoch[0] Batch [542]	Speed: 911.61 samples/sec	mse=43414164160.000000
# INFO:root:Epoch[0] Batch [544]	Speed: 790.48 samples/sec	mse=8105902336.000000
# INFO:root:Epoch[0] Batch [546]	Speed: 780.63 samples/sec	mse=8176010496.000000
# INFO:root:Epoch[0] Batch [548]	Speed: 839.62 samples/sec	mse=191752520.000000
# INFO:root:Epoch[0] Batch [550]	Speed: 913.59 samples/sec	mse=16338482688.000000
# INFO:root:Epoch[0] Batch [552]	Speed: 727.61 samples/sec	mse=2410327803.609375
# INFO:root:Epoch[0] Batch [554]	Speed: 848.19 samples/sec	mse=202771084.000000
# INFO:root:Epoch[0] Batch [556]	Speed: 948.40 samples/sec	mse=7139915648.000000
# INFO:root:Epoch[0] Batch [558]	Speed: 939.90 samples/sec	mse=1875070538.312500
# INFO:root:Epoch[0] Batch [560]	Speed: 1039.48 samples/sec	mse=2768633408.000000
# INFO:root:Epoch[0] Batch [562]	Speed: 1018.78 samples/sec	mse=2358009264.000000
# INFO:root:Epoch[0] Batch [564]	Speed: 975.08 samples/sec	mse=778712739.000000
# INFO:root:Epoch[0] Batch [566]	Speed: 678.42 samples/sec	mse=7436944128.000000
# INFO:root:Epoch[0] Batch [568]	Speed: 809.63 samples/sec	mse=748797568.000000
# INFO:root:Epoch[0] Batch [570]	Speed: 1407.48 samples/sec	mse=1901520256.000000
# INFO:root:Epoch[0] Batch [572]	Speed: 849.31 samples/sec	mse=41196782592.000000
# INFO:root:Epoch[0] Batch [574]	Speed: 887.78 samples/sec	mse=10081695744.000000
# INFO:root:Epoch[0] Batch [576]	Speed: 740.72 samples/sec	mse=21395473408.000000
# INFO:root:Epoch[0] Batch [578]	Speed: 775.57 samples/sec	mse=7001831168.000000
# INFO:root:Epoch[0] Batch [580]	Speed: 856.59 samples/sec	mse=4314372736.000000
# INFO:root:Epoch[0] Batch [582]	Speed: 1213.81 samples/sec	mse=30574167040.000000
# INFO:root:Epoch[0] Batch [584]	Speed: 917.79 samples/sec	mse=986745416.000000
# INFO:root:Epoch[0] Batch [586]	Speed: 1141.00 samples/sec	mse=107398573081.000000
# INFO:root:Epoch[0] Batch [588]	Speed: 956.95 samples/sec	mse=1585212736.000000
# INFO:root:Epoch[0] Batch [590]	Speed: 936.86 samples/sec	mse=56434051072.000000
# INFO:root:Epoch[0] Batch [592]	Speed: 1033.59 samples/sec	mse=19722552320.000000
# INFO:root:Epoch[0] Batch [594]	Speed: 1150.07 samples/sec	mse=1259467520.000000
# INFO:root:Epoch[0] Batch [596]	Speed: 1068.88 samples/sec	mse=46533898240.000000
# INFO:root:Epoch[0] Batch [598]	Speed: 1036.78 samples/sec	mse=3006441408.000000
# INFO:root:Epoch[0] Batch [600]	Speed: 849.65 samples/sec	mse=4783643488.000000
# INFO:root:Epoch[0] Batch [602]	Speed: 777.66 samples/sec	mse=172153808928.000000
# INFO:root:Epoch[0] Batch [604]	Speed: 978.49 samples/sec	mse=63473371136.000000
# INFO:root:Epoch[0] Batch [606]	Speed: 1291.95 samples/sec	mse=53650464768.000000
# INFO:root:Epoch[0] Batch [608]	Speed: 1035.76 samples/sec	mse=8624631808.000000
# INFO:root:Epoch[0] Batch [610]	Speed: 1076.98 samples/sec	mse=5934551040.000000
# INFO:root:Epoch[0] Batch [612]	Speed: 756.75 samples/sec	mse=36848635904.000000
# INFO:root:Epoch[0] Batch [614]	Speed: 905.80 samples/sec	mse=15214290944.000000
# INFO:root:Epoch[0] Batch [616]	Speed: 872.99 samples/sec	mse=5396651328.000000
# INFO:root:Epoch[0] Batch [618]	Speed: 1049.76 samples/sec	mse=8063705472.000000
# INFO:root:Epoch[0] Batch [620]	Speed: 1252.40 samples/sec	mse=23200802816.000000
# INFO:root:Epoch[0] Batch [622]	Speed: 1095.98 samples/sec	mse=7871086080.000000
# INFO:root:Epoch[0] Batch [624]	Speed: 751.87 samples/sec	mse=6199773440.000000
# INFO:root:Epoch[0] Batch [626]	Speed: 1030.41 samples/sec	mse=10789849891.906250
# INFO:root:Epoch[0] Batch [628]	Speed: 851.03 samples/sec	mse=1151216832.000000
# INFO:root:Epoch[0] Batch [630]	Speed: 913.59 samples/sec	mse=26184883904.000000
# INFO:root:Epoch[0] Batch [632]	Speed: 1165.57 samples/sec	mse=5950760064.000000
# INFO:root:Epoch[0] Batch [634]	Speed: 882.92 samples/sec	mse=5284156224.000000
# INFO:root:Epoch[0] Batch [636]	Speed: 844.26 samples/sec	mse=117338138624.000000
# INFO:root:Epoch[0] Batch [638]	Speed: 1034.61 samples/sec	mse=58963630080.000000
# INFO:root:Epoch[0] Batch [640]	Speed: 1085.06 samples/sec	mse=33336820736.000000
# INFO:root:Epoch[0] Batch [642]	Speed: 1148.18 samples/sec	mse=3372437430.000000
# INFO:root:Epoch[0] Batch [644]	Speed: 1239.27 samples/sec	mse=3000506072.000000
# INFO:root:Epoch[0] Batch [646]	Speed: 907.37 samples/sec	mse=15658505728.000000
# INFO:root:Epoch[0] Batch [648]	Speed: 983.31 samples/sec	mse=4053241984.000000
# INFO:root:Epoch[0] Batch [650]	Speed: 962.77 samples/sec	mse=22346213992.000000
# INFO:root:Epoch[0] Batch [652]	Speed: 1199.74 samples/sec	mse=3293538152.000000
# INFO:root:Epoch[0] Batch [654]	Speed: 1175.04 samples/sec	mse=4462298624.000000
# INFO:root:Epoch[0] Batch [656]	Speed: 1181.99 samples/sec	mse=13910262272.000000
# INFO:root:Epoch[0] Batch [658]	Speed: 1067.93 samples/sec	mse=18679818752.000000
# INFO:root:Epoch[0] Batch [660]	Speed: 942.96 samples/sec	mse=10028505088.000000
# INFO:root:Epoch[0] Batch [662]	Speed: 814.98 samples/sec	mse=3638990976.000000
# INFO:root:Epoch[0] Batch [664]	Speed: 954.23 samples/sec	mse=5432474240.000000
# INFO:root:Epoch[0] Batch [666]	Speed: 878.66 samples/sec	mse=1911402156.000000
# INFO:root:Epoch[0] Batch [668]	Speed: 1106.09 samples/sec	mse=188906485.000000
# INFO:root:Epoch[0] Batch [670]	Speed: 1247.75 samples/sec	mse=3771102056.000000
# INFO:root:Epoch[0] Batch [672]	Speed: 667.78 samples/sec	mse=194806877.000000
# INFO:root:Epoch[0] Batch [674]	Speed: 978.38 samples/sec	mse=387522732.000000
# INFO:root:Epoch[0] Batch [676]	Speed: 864.72 samples/sec	mse=6631541248.000000
# INFO:root:Epoch[0] Batch [678]	Speed: 805.51 samples/sec	mse=9797253632.000000
# INFO:root:Epoch[0] Batch [680]	Speed: 909.93 samples/sec	mse=5701600256.000000
# INFO:root:Epoch[0] Batch [682]	Speed: 972.25 samples/sec	mse=16602491264.000000
# INFO:root:Epoch[0] Batch [684]	Speed: 856.85 samples/sec	mse=4305323008.000000
# INFO:root:Epoch[0] Batch [686]	Speed: 985.39 samples/sec	mse=13603166176.000000
# INFO:root:Epoch[0] Batch [688]	Speed: 841.05 samples/sec	mse=13996066976.000000
# INFO:root:Epoch[0] Batch [690]	Speed: 684.45 samples/sec	mse=1881587184.000000
# INFO:root:Epoch[0] Batch [692]	Speed: 717.16 samples/sec	mse=2212169952.914062
# INFO:root:Epoch[0] Batch [694]	Speed: 739.08 samples/sec	mse=32323759744.000000
# INFO:root:Epoch[0] Batch [696]	Speed: 685.18 samples/sec	mse=13099673728.000000
# INFO:root:Epoch[0] Batch [698]	Speed: 992.97 samples/sec	mse=2805214240.000000
# INFO:root:Epoch[0] Batch [700]	Speed: 1043.88 samples/sec	mse=16673035264.000000
# INFO:root:Epoch[0] Batch [702]	Speed: 1154.82 samples/sec	mse=19292124672.000000
# INFO:root:Epoch[0] Batch [704]	Speed: 627.94 samples/sec	mse=504288976.000000
# INFO:root:Epoch[0] Batch [706]	Speed: 548.99 samples/sec	mse=15005517056.000000
# INFO:root:Epoch[0] Batch [708]	Speed: 822.41 samples/sec	mse=16019742816.000000
# INFO:root:Epoch[0] Batch [710]	Speed: 643.05 samples/sec	mse=4114413440.000000
# INFO:root:Epoch[0] Batch [712]	Speed: 1110.93 samples/sec	mse=6890533504.000000
# INFO:root:Epoch[0] Batch [714]	Speed: 747.65 samples/sec	mse=3649787648.000000
# INFO:root:Epoch[0] Batch [716]	Speed: 1142.08 samples/sec	mse=4154604112.000000
# INFO:root:Epoch[0] Batch [718]	Speed: 1040.00 samples/sec	mse=14421702144.000000
# INFO:root:Epoch[0] Batch [720]	Speed: 808.07 samples/sec	mse=3198472320.000000
# INFO:root:Epoch[0] Batch [722]	Speed: 796.87 samples/sec	mse=5201374786.875000
# INFO:root:Epoch[0] Batch [724]	Speed: 1033.08 samples/sec	mse=32455069696.000000
# INFO:root:Epoch[0] Batch [726]	Speed: 1145.36 samples/sec	mse=23317418864.000000
# INFO:root:Epoch[0] Batch [728]	Speed: 1036.27 samples/sec	mse=13598648320.000000
# INFO:root:Epoch[0] Batch [730]	Speed: 1061.98 samples/sec	mse=248596200.000000
# INFO:root:Epoch[0] Batch [732]	Speed: 1037.94 samples/sec	mse=21031970304.000000
# INFO:root:Epoch[0] Batch [734]	Speed: 1127.96 samples/sec	mse=4078057152.000000
# INFO:root:Epoch[0] Batch [736]	Speed: 780.12 samples/sec	mse=634599048.000000
# INFO:root:Epoch[0] Batch [738]	Speed: 970.79 samples/sec	mse=1601726848.000000
# INFO:root:Epoch[0] Batch [740]	Speed: 740.19 samples/sec	mse=881454240.000000
# INFO:root:Epoch[0] Batch [742]	Speed: 1069.02 samples/sec	mse=8039247680.000000
# INFO:root:Epoch[0] Batch [744]	Speed: 966.65 samples/sec	mse=1261561240.000000
# INFO:root:Epoch[0] Batch [746]	Speed: 522.04 samples/sec	mse=1445073472.000000
# INFO:root:Epoch[0] Batch [748]	Speed: 990.98 samples/sec	mse=3472269184.000000
# INFO:root:Epoch[0] Batch [750]	Speed: 902.19 samples/sec	mse=7978272622.000000
# INFO:root:Epoch[0] Batch [752]	Speed: 769.81 samples/sec	mse=173182912.000000
# INFO:root:Epoch[0] Batch [754]	Speed: 767.13 samples/sec	mse=3198381184.000000
# INFO:root:Epoch[0] Batch [756]	Speed: 913.59 samples/sec	mse=2466703548.000000
# INFO:root:Epoch[0] Batch [758]	Speed: 933.21 samples/sec	mse=7042980864.000000
# INFO:root:Epoch[0] Batch [760]	Speed: 1048.71 samples/sec	mse=1626715776.000000
# INFO:root:Epoch[0] Batch [762]	Speed: 1001.51 samples/sec	mse=490328321.000000
# INFO:root:Epoch[0] Batch [764]	Speed: 879.22 samples/sec	mse=3562686208.000000
# INFO:root:Epoch[0] Batch [766]	Speed: 1032.95 samples/sec	mse=2609307511.000000
# INFO:root:Epoch[0] Batch [768]	Speed: 1292.94 samples/sec	mse=46091195904.000000
# INFO:root:Epoch[0] Batch [770]	Speed: 1355.19 samples/sec	mse=1722558464.000000
# INFO:root:Epoch[0] Batch [772]	Speed: 1479.99 samples/sec	mse=8436823040.000000
# INFO:root:Epoch[0] Batch [774]	Speed: 1271.58 samples/sec	mse=64253024.000000
# INFO:root:Epoch[0] Batch [776]	Speed: 1004.02 samples/sec	mse=6625011968.000000
# INFO:root:Epoch[0] Batch [778]	Speed: 1103.18 samples/sec	mse=9505303504.000000
# INFO:root:Epoch[0] Batch [780]	Speed: 899.29 samples/sec	mse=1376559256.000000
# INFO:root:Epoch[0] Batch [782]	Speed: 1211.35 samples/sec	mse=16225649152.000000
# INFO:root:Epoch[0] Batch [784]	Speed: 960.56 samples/sec	mse=2940726256.000000
# INFO:root:Epoch[0] Batch [786]	Speed: 1053.85 samples/sec	mse=30940392448.000000
# INFO:root:Epoch[0] Batch [788]	Speed: 1111.81 samples/sec	mse=16301596416.000000
# INFO:root:Epoch[0] Batch [790]	Speed: 844.26 samples/sec	mse=1935320132.000000
# INFO:root:Epoch[0] Batch [792]	Speed: 1138.83 samples/sec	mse=35109673984.000000
# INFO:root:Epoch[0] Batch [794]	Speed: 1015.82 samples/sec	mse=16580605952.000000
# INFO:root:Epoch[0] Batch [796]	Speed: 982.73 samples/sec	mse=8192792320.000000
# INFO:root:Epoch[0] Batch [798]	Speed: 1347.78 samples/sec	mse=23886344704.000000
# INFO:root:Epoch[0] Batch [800]	Speed: 1405.36 samples/sec	mse=4902529304.000000
# INFO:root:Epoch[0] Batch [802]	Speed: 923.75 samples/sec	mse=6428418560.000000
# INFO:root:Epoch[0] Batch [804]	Speed: 1219.45 samples/sec	mse=5822452096.000000
# INFO:root:Epoch[0] Batch [806]	Speed: 905.80 samples/sec	mse=4540838400.000000
# INFO:root:Epoch[0] Batch [808]	Speed: 985.62 samples/sec	mse=1640806720.000000
# INFO:root:Epoch[0] Batch [810]	Speed: 989.11 samples/sec	mse=639676264.000000
# INFO:root:Epoch[0] Batch [812]	Speed: 1309.70 samples/sec	mse=9454973696.000000
# INFO:root:Epoch[0] Batch [814]	Speed: 1051.99 samples/sec	mse=5099776768.000000
# INFO:root:Epoch[0] Batch [816]	Speed: 816.33 samples/sec	mse=6485592800.000000
# INFO:root:Epoch[0] Batch [818]	Speed: 763.71 samples/sec	mse=106683486.000000
# INFO:root:Epoch[0] Batch [820]	Speed: 972.71 samples/sec	mse=4567192706.000000
# INFO:root:Epoch[0] Batch [822]	Speed: 1281.49 samples/sec	mse=11886377312.000000
# INFO:root:Epoch[0] Batch [824]	Speed: 1255.59 samples/sec	mse=4322446336.000000
# INFO:root:Epoch[0] Batch [826]	Speed: 983.77 samples/sec	mse=2638254528.000000
# INFO:root:Epoch[0] Batch [828]	Speed: 996.98 samples/sec	mse=1071763072.000000
# INFO:root:Epoch[0] Batch [830]	Speed: 1232.17 samples/sec	mse=251882476.000000
# INFO:root:Epoch[0] Batch [832]	Speed: 1212.05 samples/sec	mse=2781593376.000000
# INFO:root:Epoch[0] Batch [834]	Speed: 1094.83 samples/sec	mse=20864079032.000000
# INFO:root:Epoch[0] Batch [836]	Speed: 853.54 samples/sec	mse=22368177664.000000
# INFO:root:Epoch[0] Batch [838]	Speed: 788.92 samples/sec	mse=9818656256.000000
# INFO:root:Epoch[0] Batch [840]	Speed: 596.46 samples/sec	mse=3580821504.000000
# INFO:root:Epoch[0] Batch [842]	Speed: 870.28 samples/sec	mse=5177963168.000000
# INFO:root:Epoch[0] Batch [844]	Speed: 1160.09 samples/sec	mse=2148342464.000000
# INFO:root:Epoch[0] Batch [846]	Speed: 1057.57 samples/sec	mse=15306317312.000000
# INFO:root:Epoch[0] Batch [848]	Speed: 756.14 samples/sec	mse=4266160832.000000
# INFO:root:Epoch[0] Batch [850]	Speed: 1155.46 samples/sec	mse=2994494504.000000
# INFO:root:Epoch[0] Batch [852]	Speed: 1264.30 samples/sec	mse=17577508068.000000
# INFO:root:Epoch[0] Batch [854]	Speed: 1092.98 samples/sec	mse=29695192064.000000
# INFO:root:Epoch[0] Batch [856]	Speed: 1004.02 samples/sec	mse=12066537472.000000
# INFO:root:Epoch[0] Batch [858]	Speed: 1034.61 samples/sec	mse=2974286784.000000
# INFO:root:Epoch[0] Batch [860]	Speed: 805.82 samples/sec	mse=3720684928.000000
# INFO:root:Epoch[0] Batch [862]	Speed: 876.46 samples/sec	mse=12267395584.000000
# INFO:root:Epoch[0] Batch [864]	Speed: 961.56 samples/sec	mse=13129316096.000000
# INFO:root:Epoch[0] Batch [866]	Speed: 798.08 samples/sec	mse=497714032.000000
# INFO:root:Epoch[0] Batch [868]	Speed: 909.43 samples/sec	mse=6449159840.000000
# INFO:root:Epoch[0] Batch [870]	Speed: 1164.92 samples/sec	mse=4532868992.000000
# INFO:root:Epoch[0] Batch [872]	Speed: 1038.32 samples/sec	mse=15561477632.000000
# INFO:root:Epoch[0] Batch [874]	Speed: 858.26 samples/sec	mse=7814844160.000000
# INFO:root:Epoch[0] Batch [876]	Speed: 1091.13 samples/sec	mse=25231152640.000000
# INFO:root:Epoch[0] Batch [878]	Speed: 835.69 samples/sec	mse=2433206912.000000
# INFO:root:Epoch[0] Batch [880]	Speed: 701.98 samples/sec	mse=12068340480.000000
# INFO:root:Epoch[0] Batch [882]	Speed: 899.68 samples/sec	mse=15420376320.000000
# INFO:root:Epoch[0] Batch [884]	Speed: 909.04 samples/sec	mse=8729265664.000000
# INFO:root:Epoch[0] Batch [886]	Speed: 1270.42 samples/sec	mse=14969172896.000000
# INFO:root:Epoch[0] Batch [888]	Speed: 1033.08 samples/sec	mse=10118608896.000000
# INFO:root:Epoch[0] Batch [890]	Speed: 966.65 samples/sec	mse=37678452736.000000
# INFO:root:Epoch[0] Batch [892]	Speed: 695.46 samples/sec	mse=34502310912.000000
# INFO:root:Epoch[0] Batch [894]	Speed: 1091.70 samples/sec	mse=23120108544.000000
# INFO:root:Epoch[0] Batch [896]	Speed: 1092.41 samples/sec	mse=985630976.000000
# INFO:root:Epoch[0] Batch [898]	Speed: 886.56 samples/sec	mse=12595280128.000000
# INFO:root:Epoch[0] Batch [900]	Speed: 1419.39 samples/sec	mse=30695448576.000000
# INFO:root:Epoch[0] Batch [902]	Speed: 1003.54 samples/sec	mse=93573360.000000
# INFO:root:Epoch[0] Batch [904]	Speed: 932.90 samples/sec	mse=13936608768.000000
# INFO:root:Epoch[0] Batch [906]	Speed: 840.63 samples/sec	mse=1020866704.000000
# INFO:root:Epoch[0] Batch [908]	Speed: 921.22 samples/sec	mse=8059039744.000000
# INFO:root:Epoch[0] Batch [910]	Speed: 1013.12 samples/sec	mse=2244006336.000000
# INFO:root:Epoch[0] Batch [912]	Speed: 1239.09 samples/sec	mse=17985442496.000000
# INFO:root:Epoch[0] Batch [914]	Speed: 1325.63 samples/sec	mse=15313276928.000000
# INFO:root:Epoch[0] Batch [916]	Speed: 1136.36 samples/sec	mse=19497909248.000000
# INFO:root:Epoch[0] Batch [918]	Speed: 742.62 samples/sec	mse=15518495232.000000
# INFO:root:Epoch[0] Batch [920]	Speed: 1117.29 samples/sec	mse=23025734656.000000
# INFO:root:Epoch[0] Batch [922]	Speed: 1097.70 samples/sec	mse=3772325056.000000
# INFO:root:Epoch[0] Batch [924]	Speed: 1050.41 samples/sec	mse=11792974532.000000
# INFO:root:Epoch[0] Batch [926]	Speed: 1389.07 samples/sec	mse=48072175616.000000
# INFO:root:Epoch[0] Batch [928]	Speed: 1262.01 samples/sec	mse=27932442431.750000
# INFO:root:Epoch[0] Batch [930]	Speed: 725.66 samples/sec	mse=148884869.625000
# INFO:root:Epoch[0] Batch [932]	Speed: 802.81 samples/sec	mse=58087829504.000000
# INFO:root:Epoch[0] Batch [934]	Speed: 795.58 samples/sec	mse=109017739264.000000
# INFO:root:Epoch[0] Batch [936]	Speed: 893.17 samples/sec	mse=65559109632.000000
# INFO:root:Epoch[0] Batch [938]	Speed: 972.37 samples/sec	mse=22268154880.000000
# INFO:root:Epoch[0] Batch [940]	Speed: 810.42 samples/sec	mse=26244679680.000000
# INFO:root:Epoch[0] Batch [942]	Speed: 959.79 samples/sec	mse=96512036864.000000
# INFO:root:Epoch[0] Batch [944]	Speed: 961.00 samples/sec	mse=7458912576.000000
# INFO:root:Epoch[0] Batch [946]	Speed: 794.30 samples/sec	mse=4351361664.000000
# INFO:root:Epoch[0] Batch [948]	Speed: 888.91 samples/sec	mse=13995650560.000000
# INFO:root:Epoch[0] Batch [950]	Speed: 724.15 samples/sec	mse=21943328256.000000
# INFO:root:Epoch[0] Batch [952]	Speed: 685.12 samples/sec	mse=39444854784.000000
# INFO:root:Epoch[0] Batch [954]	Speed: 1221.05 samples/sec	mse=821209376.000000
# INFO:root:Epoch[0] Batch [956]	Speed: 1147.40 samples/sec	mse=12949364480.000000
# INFO:root:Epoch[0] Batch [958]	Speed: 972.37 samples/sec	mse=198360973312.000000
# INFO:root:Epoch[0] Batch [960]	Speed: 1055.97 samples/sec	mse=12051082880.000000
# INFO:root:Epoch[0] Batch [962]	Speed: 868.12 samples/sec	mse=22534081792.000000
# INFO:root:Epoch[0] Batch [964]	Speed: 1008.61 samples/sec	mse=54744470528.000000
# INFO:root:Epoch[0] Batch [966]	Speed: 1290.16 samples/sec	mse=50053019648.000000
# INFO:root:Epoch[0] Batch [968]	Speed: 917.39 samples/sec	mse=4325370112.000000
# INFO:root:Epoch[0] Batch [970]	Speed: 755.66 samples/sec	mse=38842428160.000000
# INFO:root:Epoch[0] Batch [972]	Speed: 1053.71 samples/sec	mse=30713332624.000000
# INFO:root:Epoch[0] Batch [974]	Speed: 981.81 samples/sec	mse=1932058649.867188
# INFO:root:Epoch[0] Batch [976]	Speed: 914.89 samples/sec	mse=2473630784.000000
# INFO:root:Epoch[0] Batch [978]	Speed: 1232.89 samples/sec	mse=640757192.000000
# INFO:root:Epoch[0] Batch [980]	Speed: 1202.67 samples/sec	mse=2574879544.500000
# INFO:root:Epoch[0] Batch [982]	Speed: 1033.46 samples/sec	mse=2235416256.000000
# INFO:root:Epoch[0] Batch [984]	Speed: 1195.47 samples/sec	mse=4278700400.000000
# INFO:root:Epoch[0] Batch [986]	Speed: 1018.53 samples/sec	mse=993059638.000000
# INFO:root:Epoch[0] Batch [988]	Speed: 1031.56 samples/sec	mse=659959135.929688
# INFO:root:Epoch[0] Batch [990]	Speed: 925.89 samples/sec	mse=983367232.000000
# INFO:root:Epoch[0] Batch [992]	Speed: 998.05 samples/sec	mse=2852160256.000000
# INFO:root:Epoch[0] Batch [994]	Speed: 1178.51 samples/sec	mse=127426237.000000
# INFO:root:Epoch[0] Batch [996]	Speed: 831.30 samples/sec	mse=1592320224.000000
# INFO:root:Epoch[0] Batch [998]	Speed: 861.70 samples/sec	mse=40404656896.000000
# INFO:root:Epoch[0] Batch [1000]	Speed: 703.45 samples/sec	mse=14353705984.000000
# INFO:root:Epoch[0] Batch [1002]	Speed: 1154.03 samples/sec	mse=662236057.000000
# INFO:root:Epoch[0] Batch [1004]	Speed: 1212.23 samples/sec	mse=8038462592.000000
# INFO:root:Epoch[0] Batch [1006]	Speed: 1017.17 samples/sec	mse=5841372416.000000
# INFO:root:Epoch[0] Batch [1008]	Speed: 871.45 samples/sec	mse=2782667904.000000
# INFO:root:Epoch[0] Batch [1010]	Speed: 890.79 samples/sec	mse=5217178112.000000
# INFO:root:Epoch[0] Batch [1012]	Speed: 808.07 samples/sec	mse=35852904448.000000
# INFO:root:Epoch[0] Batch [1014]	Speed: 863.29 samples/sec	mse=6417649359.625000
# INFO:root:Epoch[0] Batch [1016]	Speed: 938.53 samples/sec	mse=11108275328.000000
# INFO:root:Epoch[0] Batch [1018]	Speed: 936.75 samples/sec	mse=29235552256.000000
# INFO:root:Epoch[0] Batch [1020]	Speed: 1162.02 samples/sec	mse=12158498560.000000
# INFO:root:Epoch[0] Batch [1022]	Speed: 1375.41 samples/sec	mse=10348292096.000000
# INFO:root:Epoch[0] Batch [1024]	Speed: 1209.08 samples/sec	mse=2939139328.000000
# INFO:root:Epoch[0] Batch [1026]	Speed: 959.79 samples/sec	mse=26696276480.000000
# INFO:root:Epoch[0] Batch [1028]	Speed: 973.16 samples/sec	mse=23667595776.000000
# INFO:root:Epoch[0] Batch [1030]	Speed: 978.49 samples/sec	mse=3643342992.000000
# INFO:root:Epoch[0] Batch [1032]	Speed: 1347.78 samples/sec	mse=10444818688.000000
# INFO:root:Epoch[0] Batch [1034]	Speed: 834.36 samples/sec	mse=20107527168.000000
# INFO:root:Epoch[0] Batch [1036]	Speed: 1044.92 samples/sec	mse=1611183168.000000
# INFO:root:Epoch[0] Batch [1038]	Speed: 1187.01 samples/sec	mse=2444549616.000000
# INFO:root:Epoch[0] Batch [1040]	Speed: 993.56 samples/sec	mse=18614744576.000000
# INFO:root:Epoch[0] Batch [1042]	Speed: 835.77 samples/sec	mse=46592345644.000000
# INFO:root:Epoch[0] Batch [1044]	Speed: 1017.29 samples/sec	mse=7210673792.000000
# INFO:root:Epoch[0] Batch [1046]	Speed: 906.58 samples/sec	mse=20838252544.000000
# INFO:root:Epoch[0] Batch [1048]	Speed: 950.66 samples/sec	mse=9414093056.000000
# INFO:root:Epoch[0] Batch [1050]	Speed: 1287.98 samples/sec	mse=1943377088.000000
# INFO:root:Epoch[0] Batch [1052]	Speed: 1295.34 samples/sec	mse=18149237248.000000
# INFO:root:Epoch[0] Batch [1054]	Speed: 902.87 samples/sec	mse=5235000448.000000
# INFO:root:Epoch[0] Batch [1056]	Speed: 1164.92 samples/sec	mse=2065158016.000000
# INFO:root:Epoch[0] Batch [1058]	Speed: 896.41 samples/sec	mse=9454509568.000000
# INFO:root:Epoch[0] Batch [1060]	Speed: 622.49 samples/sec	mse=55752117.000000
# INFO:root:Epoch[0] Batch [1062]	Speed: 986.66 samples/sec	mse=11131608960.000000
# INFO:root:Epoch[0] Batch [1064]	Speed: 924.16 samples/sec	mse=6011475184.000000
# INFO:root:Epoch[0] Batch [1066]	Speed: 1275.64 samples/sec	mse=1399853578.000000
# INFO:root:Epoch[0] Batch [1068]	Speed: 1314.21 samples/sec	mse=173404788.000000
# INFO:root:Epoch[0] Batch [1070]	Speed: 878.02 samples/sec	mse=3330727296.000000
# INFO:root:Epoch[0] Batch [1072]	Speed: 928.05 samples/sec	mse=24103214848.000000
# INFO:root:Epoch[0] Batch [1074]	Speed: 732.37 samples/sec	mse=1737643616.000000
# INFO:root:Epoch[0] Batch [1076]	Speed: 996.51 samples/sec	mse=9931437184.000000
# INFO:root:Epoch[0] Batch [1078]	Speed: 1228.38 samples/sec	mse=7790493664.000000
# INFO:root:Epoch[0] Batch [1080]	Speed: 970.34 samples/sec	mse=7269954.750000
# INFO:root:Epoch[0] Batch [1082]	Speed: 1227.66 samples/sec	mse=2290570488.000000
# INFO:root:Epoch[0] Batch [1084]	Speed: 1058.77 samples/sec	mse=1551564615.000000
# INFO:root:Epoch[0] Batch [1086]	Speed: 1204.91 samples/sec	mse=51316015488.000000
# INFO:root:Epoch[0] Batch [1088]	Speed: 1061.58 samples/sec	mse=10537226752.000000
# INFO:root:Epoch[0] Batch [1090]	Speed: 931.96 samples/sec	mse=4855492096.000000
# INFO:root:Epoch[0] Batch [1092]	Speed: 1026.25 samples/sec	mse=831221874.000000
# INFO:root:Epoch[0] Batch [1094]	Speed: 856.50 samples/sec	mse=20376875545.000000
# INFO:root:Epoch[0] Batch [1096]	Speed: 940.74 samples/sec	mse=2297883738.000000
# INFO:root:Epoch[0] Batch [1098]	Speed: 897.27 samples/sec	mse=9839927168.000000
# INFO:root:Epoch[0] Batch [1100]	Speed: 970.01 samples/sec	mse=3307138328.000000
# INFO:root:Epoch[0] Batch [1102]	Speed: 879.86 samples/sec	mse=316230620.000000
# INFO:root:Epoch[0] Batch [1104]	Speed: 955.53 samples/sec	mse=7740444544.000000
# INFO:root:Epoch[0] Batch [1106]	Speed: 837.86 samples/sec	mse=2557842432.000000
# INFO:root:Epoch[0] Batch [1108]	Speed: 902.19 samples/sec	mse=1054293040.000000
# INFO:root:Epoch[0] Batch [1110]	Speed: 1085.62 samples/sec	mse=602136973.000000
# INFO:root:Epoch[0] Batch [1112]	Speed: 818.32 samples/sec	mse=10713186304.000000
# INFO:root:Epoch[0] Batch [1114]	Speed: 910.32 samples/sec	mse=9061073920.000000
# INFO:root:Epoch[0] Batch [1116]	Speed: 1113.58 samples/sec	mse=1468418144.000000
# INFO:root:Epoch[0] Batch [1118]	Speed: 1027.76 samples/sec	mse=1216815304.000000
# INFO:root:Epoch[0] Batch [1120]	Speed: 976.10 samples/sec	mse=21711153664.000000
# INFO:root:Epoch[0] Batch [1122]	Speed: 1066.17 samples/sec	mse=185089008.000000
# INFO:root:Epoch[0] Batch [1124]	Speed: 1014.71 samples/sec	mse=337052520.000000
# INFO:root:Epoch[0] Batch [1126]	Speed: 1155.93 samples/sec	mse=9591232448.000000
# INFO:root:Epoch[0] Batch [1128]	Speed: 901.32 samples/sec	mse=5107024640.000000
# INFO:root:Epoch[0] Batch [1130]	Speed: 636.95 samples/sec	mse=110427478.500000
# INFO:root:Epoch[0] Batch [1132]	Speed: 933.10 samples/sec	mse=1025039936.000000
# INFO:root:Epoch[0] Batch [1134]	Speed: 917.79 samples/sec	mse=12339824320.000000
# INFO:root:Epoch[0] Batch [1136]	Speed: 1131.91 samples/sec	mse=16431049888.000000
# INFO:root:Epoch[0] Batch [1138]	Speed: 1023.13 samples/sec	mse=8900454656.000000
# INFO:root:Epoch[0] Batch [1140]	Speed: 979.86 samples/sec	mse=14741190912.000000
# INFO:root:Epoch[0] Batch [1142]	Speed: 1092.27 samples/sec	mse=12432316672.000000
# INFO:root:Epoch[0] Batch [1144]	Speed: 1178.51 samples/sec	mse=2725296000.000000
# INFO:root:Epoch[0] Batch [1146]	Speed: 536.73 samples/sec	mse=4957228672.000000
# INFO:root:Epoch[0] Batch [1148]	Speed: 962.55 samples/sec	mse=3930683520.000000
# INFO:root:Epoch[0] Batch [1150]	Speed: 821.69 samples/sec	mse=5370057088.000000
# INFO:root:Epoch[0] Batch [1152]	Speed: 730.46 samples/sec	mse=4050446976.000000
# INFO:root:Epoch[0] Batch [1154]	Speed: 1036.78 samples/sec	mse=15934469120.000000
# INFO:root:Epoch[0] Batch [1156]	Speed: 999.00 samples/sec	mse=27362418688.000000
# INFO:root:Epoch[0] Batch [1158]	Speed: 1047.79 samples/sec	mse=19847379996.000000
# INFO:root:Epoch[0] Batch [1160]	Speed: 1065.90 samples/sec	mse=3194537792.000000
# INFO:root:Epoch[0] Batch [1162]	Speed: 902.97 samples/sec	mse=253866318.000000
# INFO:root:Epoch[0] Batch [1164]	Speed: 1213.63 samples/sec	mse=37513488128.000000
# INFO:root:Epoch[0] Batch [1166]	Speed: 979.86 samples/sec	mse=3219857772.000000
# INFO:root:Epoch[0] Batch [1168]	Speed: 814.98 samples/sec	mse=3250362272.000000
# INFO:root:Epoch[0] Batch [1170]	Speed: 1191.39 samples/sec	mse=4030297016.000000
# INFO:root:Epoch[0] Batch [1172]	Speed: 1010.68 samples/sec	mse=1319929963.000000
# INFO:root:Epoch[0] Batch [1174]	Speed: 1260.31 samples/sec	mse=83540162912.000000
# INFO:root:Epoch[0] Batch [1176]	Speed: 365.90 samples/sec	mse=9216921088.000000
# INFO:root:Epoch[0] Batch [1178]	Speed: 1044.40 samples/sec	mse=1499429344.000000
# INFO:root:Epoch[0] Batch [1180]	Speed: 1246.08 samples/sec	mse=8798136064.000000
# INFO:root:Epoch[0] Batch [1182]	Speed: 1135.74 samples/sec	mse=1884788672.000000
# INFO:root:Epoch[0] Batch [1184]	Speed: 962.44 samples/sec	mse=1151245316.000000
# INFO:root:Epoch[0] Batch [1186]	Speed: 803.51 samples/sec	mse=19734124544.000000
# INFO:root:Epoch[0] Batch [1188]	Speed: 1261.82 samples/sec	mse=2942297792.000000
# INFO:root:Epoch[0] Batch [1190]	Speed: 754.64 samples/sec	mse=7424069376.000000
# INFO:root:Epoch[0] Batch [1192]	Speed: 1158.81 samples/sec	mse=22983203840.000000
# INFO:root:Epoch[0] Batch [1194]	Speed: 824.84 samples/sec	mse=2004316352.000000
# INFO:root:Epoch[0] Batch [1196]	Speed: 818.64 samples/sec	mse=5598087680.000000
# INFO:root:Epoch[0] Batch [1198]	Speed: 813.64 samples/sec	mse=5384508160.000000
# INFO:root:Epoch[0] Batch [1200]	Speed: 897.27 samples/sec	mse=6935644816.000000
# INFO:root:Epoch[0] Batch [1202]	Speed: 1205.61 samples/sec	mse=993844523.000000
# ...
# INFO:root:Epoch[43] Batch [1072]	Speed: 918.39 samples/sec	mse=24103218944.000000
# INFO:root:Epoch[43] Batch [1074]	Speed: 1100.72 samples/sec	mse=1737642016.000000
# INFO:root:Epoch[43] Batch [1076]	Speed: 848.53 samples/sec	mse=9931432064.000000
# INFO:root:Epoch[43] Batch [1078]	Speed: 1148.97 samples/sec	mse=7790493664.000000
# INFO:root:Epoch[43] Batch [1080]	Speed: 1193.94 samples/sec	mse=7269987.250000
# INFO:root:Epoch[43] Batch [1082]	Speed: 982.85 samples/sec	mse=2290569284.000000
# INFO:root:Epoch[43] Batch [1084]	Speed: 975.53 samples/sec	mse=1551562680.500000
# INFO:root:Epoch[43] Batch [1086]	Speed: 667.99 samples/sec	mse=51316007296.000000
# INFO:root:Epoch[43] Batch [1088]	Speed: 875.00 samples/sec	mse=10537228032.000000
# INFO:root:Epoch[43] Batch [1090]	Speed: 788.70 samples/sec	mse=4855491072.000000
# INFO:root:Epoch[43] Batch [1092]	Speed: 930.21 samples/sec	mse=831223154.000000
# INFO:root:Epoch[43] Batch [1094]	Speed: 913.59 samples/sec	mse=20376875465.000000
# INFO:root:Epoch[43] Batch [1096]	Speed: 1001.98 samples/sec	mse=2297882524.000000
# INFO:root:Epoch[43] Batch [1098]	Speed: 1145.36 samples/sec	mse=9839928320.000000
# INFO:root:Epoch[43] Batch [1100]	Speed: 1095.26 samples/sec	mse=3307138112.000000
# INFO:root:Epoch[43] Batch [1102]	Speed: 1056.37 samples/sec	mse=316231140.000000
# INFO:root:Epoch[43] Batch [1104]	Speed: 1201.98 samples/sec	mse=7740443136.000000
# INFO:root:Epoch[43] Batch [1106]	Speed: 1208.38 samples/sec	mse=2557842240.000000
# INFO:root:Epoch[43] Batch [1108]	Speed: 973.83 samples/sec	mse=1054293488.000000
# INFO:root:Epoch[43] Batch [1110]	Speed: 1154.03 samples/sec	mse=602136973.000000
# INFO:root:Epoch[43] Batch [1112]	Speed: 1050.02 samples/sec	mse=10713185024.000000
# INFO:root:Epoch[43] Batch [1114]	Speed: 821.69 samples/sec	mse=9061073920.000000
# INFO:root:Epoch[43] Batch [1116]	Speed: 1101.88 samples/sec	mse=1468418144.000000
# INFO:root:Epoch[43] Batch [1118]	Speed: 1013.12 samples/sec	mse=1216814920.000000
# INFO:root:Epoch[43] Batch [1120]	Speed: 843.50 samples/sec	mse=21711155712.000000
# INFO:root:Epoch[43] Batch [1122]	Speed: 944.77 samples/sec	mse=185089292.000000
# INFO:root:Epoch[43] Batch [1124]	Speed: 1039.35 samples/sec	mse=337052312.000000
# INFO:root:Epoch[43] Batch [1126]	Speed: 1017.79 samples/sec	mse=9591230688.000000
# INFO:root:Epoch[43] Batch [1128]	Speed: 761.70 samples/sec	mse=5107024672.000000
# INFO:root:Epoch[43] Batch [1130]	Speed: 1184.16 samples/sec	mse=110427254.500000
# INFO:root:Epoch[43] Batch [1132]	Speed: 1226.23 samples/sec	mse=1025039680.000000
# INFO:root:Epoch[43] Batch [1134]	Speed: 1144.89 samples/sec	mse=12339824096.000000
# INFO:root:Epoch[43] Batch [1136]	Speed: 1086.33 samples/sec	mse=16431049408.000000
# INFO:root:Epoch[43] Batch [1138]	Speed: 1169.47 samples/sec	mse=8900453376.000000
# INFO:root:Epoch[43] Batch [1140]	Speed: 734.75 samples/sec	mse=14741190400.000000
# INFO:root:Epoch[43] Batch [1142]	Speed: 557.12 samples/sec	mse=12432317440.000000
# INFO:root:Epoch[43] Batch [1144]	Speed: 838.61 samples/sec	mse=2725296000.000000
# INFO:root:Epoch[43] Batch [1146]	Speed: 1124.18 samples/sec	mse=4957228672.000000
# INFO:root:Epoch[43] Batch [1148]	Speed: 942.01 samples/sec	mse=3930683520.000000
# INFO:root:Epoch[43] Batch [1150]	Speed: 1062.79 samples/sec	mse=5370057088.000000
# INFO:root:Epoch[43] Batch [1152]	Speed: 904.63 samples/sec	mse=4050445952.000000
# INFO:root:Epoch[43] Batch [1154]	Speed: 735.26 samples/sec	mse=15934468032.000000
# INFO:root:Epoch[43] Batch [1156]	Speed: 908.35 samples/sec	mse=27362428928.000000
# INFO:root:Epoch[43] Batch [1158]	Speed: 880.69 samples/sec	mse=19847379792.000000
# INFO:root:Epoch[43] Batch [1160]	Speed: 746.65 samples/sec	mse=3194539456.000000
# INFO:root:Epoch[43] Batch [1162]	Speed: 951.95 samples/sec	mse=253866542.000000
# INFO:root:Epoch[43] Batch [1164]	Speed: 838.27 samples/sec	mse=37513497600.000000
# INFO:root:Epoch[43] Batch [1166]	Speed: 1072.44 samples/sec	mse=3219855416.000000
# INFO:root:Epoch[43] Batch [1168]	Speed: 1262.77 samples/sec	mse=3250360192.000000
# INFO:root:Epoch[43] Batch [1170]	Speed: 907.96 samples/sec	mse=4030292480.000000
# INFO:root:Epoch[43] Batch [1172]	Speed: 1191.23 samples/sec	mse=1319930648.000000
# INFO:root:Epoch[43] Batch [1174]	Speed: 845.71 samples/sec	mse=83540145568.000000
# INFO:root:Epoch[43] Batch [1176]	Speed: 980.44 samples/sec	mse=9216926848.000000
# INFO:root:Epoch[43] Batch [1178]	Speed: 1293.54 samples/sec	mse=1499430360.000000
# INFO:root:Epoch[43] Batch [1180]	Speed: 1146.77 samples/sec	mse=8798133504.000000
# INFO:root:Epoch[43] Batch [1182]	Speed: 852.93 samples/sec	mse=1884788160.000000
# INFO:root:Epoch[43] Batch [1184]	Speed: 1068.48 samples/sec	mse=1151246964.000000
# INFO:root:Epoch[43] Batch [1186]	Speed: 609.19 samples/sec	mse=19734125824.000000
# INFO:root:Epoch[43] Batch [1188]	Speed: 1090.00 samples/sec	mse=2942297920.000000
# INFO:root:Epoch[43] Batch [1190]	Speed: 845.28 samples/sec	mse=7424069632.000000
# INFO:root:Epoch[43] Batch [1192]	Speed: 729.13 samples/sec	mse=22983208960.000000
# INFO:root:Epoch[43] Batch [1194]	Speed: 924.67 samples/sec	mse=2004318208.000000
# INFO:root:Epoch[43] Batch [1196]	Speed: 775.14 samples/sec	mse=5598088448.000000
# INFO:root:Epoch[43] Batch [1198]	Speed: 786.19 samples/sec	mse=5384508672.000000
# INFO:root:Epoch[43] Batch [1200]	Speed: 858.08 samples/sec	mse=6935644934.000000
# INFO:root:Epoch[43] Batch [1202]	Speed: 1209.95 samples/sec	mse=993844474.500000
# INFO:root:Epoch[43] Batch [1204]	Speed: 1253.72 samples/sec	mse=11248038272.000000
# INFO:root:Epoch[43] Batch [1206]	Speed: 961.56 samples/sec	mse=8150131712.000000
# INFO:root:Epoch[43] Batch [1208]	Speed: 1233.80 samples/sec	mse=3067830912.000000
# INFO:root:Epoch[43] Batch [1210]	Speed: 1291.35 samples/sec	mse=3409724000.000000
# INFO:root:Epoch[43] Batch [1212]	Speed: 1089.85 samples/sec	mse=32208834816.000000
# INFO:root:Epoch[43] Batch [1214]	Speed: 762.39 samples/sec	mse=95024492544.000000
# INFO:root:Epoch[43] Batch [1216]	Speed: 1095.83 samples/sec	mse=36947665920.000000
# INFO:root:Epoch[43] Batch [1218]	Speed: 1028.77 samples/sec	mse=31450612736.000000
# INFO:root:Epoch[43] Batch [1220]	Speed: 975.19 samples/sec	mse=4686316156.000000
# INFO:root:Epoch[43] Batch [1222]	Speed: 1141.62 samples/sec	mse=4884576611.000000
# INFO:root:Epoch[43] Batch [1224]	Speed: 884.59 samples/sec	mse=40837869568.000000
# INFO:root:Epoch[43] Batch [1226]	Speed: 1250.17 samples/sec	mse=5317174688.000000
# INFO:root:Epoch[43] Batch [1228]	Speed: 1276.22 samples/sec	mse=15014905602.656250
# INFO:root:Epoch[43] Batch [1230]	Speed: 1029.78 samples/sec	mse=14217740032.000000
# INFO:root:Epoch[43] Batch [1232]	Speed: 956.84 samples/sec	mse=15305039616.000000
# INFO:root:Epoch[43] Batch [1234]	Speed: 813.95 samples/sec	mse=7603129028.000000
# INFO:root:Epoch[43] Batch [1236]	Speed: 943.39 samples/sec	mse=164271488.000000
# INFO:root:Epoch[43] Batch [1238]	Speed: 1121.02 samples/sec	mse=1609492864.000000
# INFO:root:Epoch[43] Batch [1240]	Speed: 748.18 samples/sec	mse=3006634496.000000
# INFO:root:Epoch[43] Batch [1242]	Speed: 893.17 samples/sec	mse=38680062976.000000
# INFO:root:Epoch[43] Batch [1244]	Speed: 747.38 samples/sec	mse=1945296320.000000
# INFO:root:Epoch[43] Batch [1246]	Speed: 1040.00 samples/sec	mse=6719085824.000000
# INFO:root:Epoch[43] Batch [1248]	Speed: 1120.57 samples/sec	mse=10115566080.000000
# INFO:root:Epoch[43] Batch [1250]	Speed: 904.63 samples/sec	mse=84889394.000000
# INFO:root:Epoch[43] Batch [1252]	Speed: 985.16 samples/sec	mse=4055135808.000000
# INFO:root:Epoch[43] Batch [1254]	Speed: 843.84 samples/sec	mse=215917443.000000
# INFO:root:Epoch[43] Batch [1256]	Speed: 940.74 samples/sec	mse=9755212565.546875
# INFO:root:Epoch[43] Batch [1258]	Speed: 1234.53 samples/sec	mse=7404342912.000000
# INFO:root:Epoch[43] Batch [1260]	Speed: 1172.41 samples/sec	mse=3231838656.000000
# INFO:root:Epoch[43] Batch [1262]	Speed: 899.29 samples/sec	mse=2552762848.000000
# INFO:root:Epoch[43] Batch [1264]	Speed: 948.29 samples/sec	mse=1884492288.000000
# INFO:root:Epoch[43] Batch [1266]	Speed: 1231.45 samples/sec	mse=881805696.000000
# INFO:root:Epoch[43] Batch [1268]	Speed: 745.72 samples/sec	mse=2942283136.000000
# INFO:root:Epoch[43] Batch [1270]	Speed: 808.77 samples/sec	mse=1009545192.000000
# INFO:root:Epoch[43] Batch [1272]	Speed: 1192.58 samples/sec	mse=1442218656.000000
# INFO:root:Epoch[43] Batch [1274]	Speed: 1041.67 samples/sec	mse=566037984.000000
# INFO:root:Epoch[43] Batch [1276]	Speed: 1116.69 samples/sec	mse=2087723440.000000
# INFO:root:Epoch[43] Batch [1278]	Speed: 945.20 samples/sec	mse=64060216704.000000
# INFO:root:Epoch[43] Batch [1280]	Speed: 981.35 samples/sec	mse=5273738496.000000
# INFO:root:Epoch[43] Batch [1282]	Speed: 991.09 samples/sec	mse=1284564264.000000
# INFO:root:Epoch[43] Batch [1284]	Speed: 816.65 samples/sec	mse=37455719424.000000
# INFO:root:Epoch[43] Batch [1286]	Speed: 1134.98 samples/sec	mse=24983835136.000000
# INFO:root:Epoch[43] Batch [1288]	Speed: 988.99 samples/sec	mse=8757243392.000000
# INFO:root:Epoch[43] Batch [1290]	Speed: 922.53 samples/sec	mse=8306898880.000000
# INFO:root:Epoch[43] Batch [1292]	Speed: 884.59 samples/sec	mse=49759544320.000000
# INFO:root:Epoch[43] Batch [1294]	Speed: 931.96 samples/sec	mse=9201202656.000000
# INFO:root:Epoch[43] Batch [1296]	Speed: 1057.57 samples/sec	mse=15229209088.000000
# INFO:root:Epoch[43] Batch [1298]	Speed: 874.18 samples/sec	mse=20206931456.000000
# INFO:root:Epoch[43] Batch [1300]	Speed: 726.48 samples/sec	mse=30844891136.000000
# INFO:root:Epoch[43] Batch [1302]	Speed: 906.29 samples/sec	mse=9789703936.000000
# INFO:root:Epoch[43] Batch [1304]	Speed: 827.36 samples/sec	mse=8730939008.000000
# INFO:root:Epoch[43] Batch [1306]	Speed: 982.73 samples/sec	mse=8187425664.000000
# INFO:root:Epoch[43] Batch [1308]	Speed: 1248.30 samples/sec	mse=21386404864.000000
# INFO:root:Epoch[43] Batch [1310]	Speed: 836.44 samples/sec	mse=11977940736.000000
# INFO:root:Epoch[43] Batch [1312]	Speed: 1099.57 samples/sec	mse=3877471872.000000
# INFO:root:Epoch[43] Batch [1314]	Speed: 561.34 samples/sec	mse=45081167872.000000
# INFO:root:Epoch[43] Batch [1316]	Speed: 918.29 samples/sec	mse=9627437039.625000
# INFO:root:Epoch[43] Batch [1318]	Speed: 1189.20 samples/sec	mse=4502356952.000000
# INFO:root:Epoch[43] Batch [1320]	Speed: 821.69 samples/sec	mse=113738170368.000000
# INFO:root:Epoch[43] Batch [1322]	Speed: 909.04 samples/sec	mse=6530746676.000000
# INFO:root:Epoch[43] Batch [1324]	Speed: 1035.12 samples/sec	mse=13723091456.000000
# INFO:root:Epoch[43] Batch [1326]	Speed: 1177.84 samples/sec	mse=30903346688.000000
# INFO:root:Epoch[43] Batch [1328]	Speed: 1113.43 samples/sec	mse=5687409408.000000
# INFO:root:Epoch[43] Batch [1330]	Speed: 862.40 samples/sec	mse=57382113280.000000
# INFO:root:Epoch[43] Batch [1332]	Speed: 872.18 samples/sec	mse=5526255328.000000
# INFO:root:Epoch[43] Batch [1334]	Speed: 851.46 samples/sec	mse=7613168448.000000
# INFO:root:Epoch[43] Batch [1336]	Speed: 648.12 samples/sec	mse=5061791104.000000
# INFO:root:Epoch[43] Batch [1338]	Speed: 825.00 samples/sec	mse=12670620280.000000
# INFO:root:Epoch[43] Batch [1340]	Speed: 1037.81 samples/sec	mse=34039205408.000000
# INFO:root:Epoch[43] Batch [1342]	Speed: 1314.01 samples/sec	mse=12732879872.000000
# INFO:root:Epoch[43] Batch [1344]	Speed: 1123.57 samples/sec	mse=2127866560.000000
# INFO:root:Epoch[43] Batch [1346]	Speed: 896.22 samples/sec	mse=2093321088.000000
# INFO:root:Epoch[43] Batch [1348]	Speed: 884.22 samples/sec	mse=1630754432.000000
# INFO:root:Epoch[43] Batch [1350]	Speed: 950.01 samples/sec	mse=17295941632.000000
# INFO:root:Epoch[43] Batch [1352]	Speed: 1089.29 samples/sec	mse=3362246752.000000
# INFO:root:Epoch[43] Batch [1354]	Speed: 937.27 samples/sec	mse=93116327.000000
# INFO:root:Epoch[43] Batch [1356]	Speed: 756.41 samples/sec	mse=830056672.000000
# INFO:root:Epoch[43] Batch [1358]	Speed: 945.62 samples/sec	mse=3233955224.000000
# INFO:root:Epoch[43] Batch [1360]	Speed: 1118.63 samples/sec	mse=1301408512.000000
# INFO:root:Epoch[43] Batch [1362]	Speed: 1031.94 samples/sec	mse=5156766656.000000
# INFO:root:Epoch[43] Batch [1364]	Speed: 1035.76 samples/sec	mse=11188225024.000000
# INFO:root:Epoch[43] Batch [1366]	Speed: 985.74 samples/sec	mse=5645504576.000000
# INFO:root:Epoch[43] Batch [1368]	Speed: 876.37 samples/sec	mse=18024396608.000000
# INFO:root:Epoch[43] Batch [1370]	Speed: 805.51 samples/sec	mse=437530824.000000
# INFO:root:Epoch[43] Batch [1372]	Speed: 818.00 samples/sec	mse=4640915776.000000
# INFO:root:Epoch[43] Batch [1374]	Speed: 1186.51 samples/sec	mse=5066713600.000000
# INFO:root:Epoch[43] Batch [1376]	Speed: 1139.60 samples/sec	mse=4813889248.000000
# INFO:root:Epoch[43] Batch [1378]	Speed: 954.77 samples/sec	mse=1359862720.000000
# INFO:root:Epoch[43] Batch [1380]	Speed: 751.60 samples/sec	mse=21924676352.000000
# INFO:root:Epoch[43] Batch [1382]	Speed: 942.01 samples/sec	mse=71032821248.000000
# INFO:root:Epoch[43] Batch [1384]	Speed: 842.40 samples/sec	mse=24196304128.000000
# INFO:root:Epoch[43] Batch [1386]	Speed: 1007.04 samples/sec	mse=35032999936.000000
# INFO:root:Epoch[43] Batch [1388]	Speed: 847.42 samples/sec	mse=15504959488.000000
# INFO:root:Epoch[43] Batch [1390]	Speed: 845.37 samples/sec	mse=6577451640.000000
# INFO:root:Epoch[43] Batch [1392]	Speed: 783.62 samples/sec	mse=1668093782.000000
# INFO:root:Epoch[43] Batch [1394]	Speed: 904.04 samples/sec	mse=18092440064.000000
# INFO:root:Epoch[43] Batch [1396]	Speed: 1115.51 samples/sec	mse=12578807552.000000
# INFO:root:Epoch[43] Batch [1398]	Speed: 1453.58 samples/sec	mse=6534071542.000000
# INFO:root:Epoch[43] Batch [1400]	Speed: 872.90 samples/sec	mse=17806066176.000000
# INFO:root:Epoch[43] Batch [1402]	Speed: 1040.00 samples/sec	mse=7128201600.000000
# INFO:root:Epoch[43] Batch [1404]	Speed: 1136.36 samples/sec	mse=23372450368.000000
# INFO:root:Epoch[43] Batch [1406]	Speed: 1040.64 samples/sec	mse=3443957376.000000
# INFO:root:Epoch[43] Batch [1408]	Speed: 913.99 samples/sec	mse=1520731152.000000
# INFO:root:Epoch[43] Batch [1410]	Speed: 851.03 samples/sec	mse=6911014656.000000
# INFO:root:Epoch[43] Batch [1412]	Speed: 1102.02 samples/sec	mse=11951973504.000000
# INFO:root:Epoch[43] Batch [1414]	Speed: 833.69 samples/sec	mse=8314263488.000000
# INFO:root:Epoch[43] Batch [1416]	Speed: 841.64 samples/sec	mse=2681212608.000000
# INFO:root:Epoch[43] Batch [1418]	Speed: 1011.16 samples/sec	mse=1859610897.750000
# INFO:root:Epoch[43] Batch [1420]	Speed: 1025.13 samples/sec	mse=31814592512.000000
# INFO:root:Epoch[43] Batch [1422]	Speed: 922.53 samples/sec	mse=6048267520.000000
# INFO:root:Epoch[43] Batch [1424]	Speed: 1053.18 samples/sec	mse=3917191296.000000
# INFO:root:Epoch[43] Batch [1426]	Speed: 977.47 samples/sec	mse=10272492928.000000
# INFO:root:Epoch[43] Batch [1428]	Speed: 744.07 samples/sec	mse=4517538048.000000
# INFO:root:Epoch[43] Batch [1430]	Speed: 910.72 samples/sec	mse=5628009600.000000
# INFO:root:Epoch[43] Batch [1432]	Speed: 793.32 samples/sec	mse=242154100.000000
# INFO:root:Epoch[43] Batch [1434]	Speed: 1197.69 samples/sec	mse=5090739584.000000
# INFO:root:Epoch[43] Batch [1436]	Speed: 1016.80 samples/sec	mse=218826536.000000
# INFO:root:Epoch[43] Batch [1438]	Speed: 1051.99 samples/sec	mse=1410452664.000000
# INFO:root:Epoch[43] Batch [1440]	Speed: 810.42 samples/sec	mse=8472066240.000000
# INFO:root:Epoch[43] Batch [1442]	Speed: 1153.39 samples/sec	mse=2335670720.000000
# INFO:root:Epoch[43] Batch [1444]	Speed: 1141.46 samples/sec	mse=21537504256.000000
# INFO:root:Epoch[43] Batch [1446]	Speed: 838.94 samples/sec	mse=15972478976.000000
# INFO:root:Epoch[43] Batch [1448]	Speed: 1372.93 samples/sec	mse=6081859072.000000
# INFO:root:Epoch[43] Batch [1450]	Speed: 1015.32 samples/sec	mse=18182250336.000000
# INFO:root:Epoch[43] Batch [1452]	Speed: 1166.22 samples/sec	mse=2235864960.000000
# INFO:root:Epoch[43] Batch [1454]	Speed: 971.35 samples/sec	mse=30575859456.000000
# INFO:root:Epoch[43] Batch [1456]	Speed: 1086.33 samples/sec	mse=10459452416.000000
# INFO:root:Epoch[43] Batch [1458]	Speed: 807.76 samples/sec	mse=5395022592.000000
# INFO:root:Epoch[43] Train-mse=138214928.000000
# INFO:root:Epoch[43] Time cost=2.058

# %% [markdown]
# ## Using a trained model: (Testing and Inference)
#
# Once we have a trained model, we can do a couple of things with it - we can either
# use it for inference or we can evaluate the trained model on test data. The latter is shown below:

# %%
model.predict(eval_iter).asnumpy()

# %% [markdown]
# We can also evaluate our model according to some metric. In this example, we are
# evaluating our model's mean squared error (MSE) on the evaluation data.

# %%
metric = mx.metric.MSE()
model.score(eval_iter, metric)

# %% [markdown]
# Let us try and add some noise to the evaluation data and see how the MSE changes:

# %%
eval_data = np.array([[7,2],[6,10],[12,2]])
eval_label = np.array([11.1,26.1,16.1]) #Adding 0.1 to each of the values
eval_iter = mx.io.NDArrayIter(eval_data, eval_label, batch_size, shuffle=False)
model.score(eval_iter, metric)

# %% [markdown]
# We can also create a custom metric and use it to evaluate a model. More
# information on metrics can be found in the [API documentation](http://mxnet.io/api/python/model.html#evaluation-metric-api-reference).
#
# <!-- INSERT SOURCE DOWNLOAD BUTTONS -->
